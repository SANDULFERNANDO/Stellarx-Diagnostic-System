# %% [markdown]
# <a href="https://colab.research.google.com/github/SANDULFERNANDO/Stellarx-Diagnostic-System/blob/feature%2FDenseNet-model/denseNet_changed_model_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
TRAIN_DIR = "/content/drive/MyDrive/dataset/Train"
VAL_DIR   = "/content/drive/MyDrive/dataset/Validation"
TEST_DIR  = "/content/drive/MyDrive/dataset/Test"

# %%
import os

print("Train:", os.listdir(TRAIN_DIR))
print("Validation:", os.listdir(VAL_DIR))
print("Test:", os.listdir(TEST_DIR))
# Out:
# Train: ['Tinea', 'Leishmaniasis', 'Eczema']
# Validation: ['Tinea', 'Eczema', 'Leishmaniasis']
# Test: ['Leishmaniasis', 'Eczema', 'Tinea']

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from tensorflow.keras.applications import DenseNet121
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

from sklearn.metrics import confusion_matrix, classification_report

# %%
IMG_SIZE = (224, 224)
BATCH_SIZE = 32
SEED = 42

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
    TRAIN_DIR,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    label_mode="categorical",
    shuffle=True,
    seed=SEED
)
# Out:
# Found 2688 files belonging to 3 classes.

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
    VAL_DIR,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    label_mode="categorical",
    shuffle=False
)
# Out:
# Found 574 files belonging to 3 classes.

# %%
test_ds = tf.keras.utils.image_dataset_from_directory(
    TEST_DIR,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    label_mode="categorical",
    shuffle=False
)
# Out:
# Found 573 files belonging to 3 classes.

# %%
class_names = train_ds.class_names

print("Classes:", class_names)
print("Number of classes:", len(class_names))
# Out:
# Classes: ['Eczema', 'Leishmaniasis', 'Tinea']
# Number of classes: 3

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.prefetch(AUTOTUNE)
val_ds = val_ds.prefetch(AUTOTUNE)
test_ds = test_ds.prefetch(AUTOTUNE)

# %%
base_model = DenseNet121(
    weights="imagenet",
    include_top=False,
    input_shape=(224, 224, 3)
)

base_model.trainable = False
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29084464/29084464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
num_classes = len(class_names)

model = Sequential([
    base_model,

    GlobalAveragePooling2D(),

    Dense(512, activation="relu"),

    Dropout(0.5),

    Dense(num_classes, activation="softmax")
])

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)

# %%
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ densenet121 (Functional)        │ (None, 7, 7, 1024)     │     7,037,504 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_2      │ (None, 1024)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 512)            │       524,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 3)              │         1,539 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 7,563,843 (28.85 MB)
#  Trainable params: 526,339 (2.01 MB)
#  Non-trainable params: 7,037,504 (26.85 MB)

# %%
early_stopping = EarlyStopping(
    monitor="val_loss",
    patience=5,
    restore_best_weights=True
)

reduce_lr = ReduceLROnPlateau(
    monitor="val_loss",
    factor=0.2,
    patience=2,
    min_lr=1e-7
)

# %%
EPOCHS = 30

history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS,
    callbacks=[
        early_stopping,
        reduce_lr
    ]
)
# Out:
# Epoch 1/30
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 689s 8s/step - accuracy: 0.6016 - loss: 1.8926 - val_accuracy: 0.7840 - val_loss: 0.7111 - learning_rate: 1.0000e-04
# Epoch 2/30
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 722s 9s/step - accuracy: 0.7355 - loss: 0.9570 - val_accuracy: 0.8206 - val_loss: 0.5630 - learning_rate: 1.0000e-04
# Epoch 3/30
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 675s 8s/step - accuracy: 0.7898 - loss: 0.6623 - val_accuracy: 0.8345 - val_loss: 0.4723 - learning_rate: 1.0000e-04
# Epoch 4/30
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 664s 8s/step - accuracy: 0.8307 - loss: 0.4916 - val_accuracy: 0.8345 - val_loss: 0.4712 - learning_rate: 1.0000e-04
# Epoch 5/30
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 665s 8s/step - accuracy: 0.8471 - loss: 0.4367 - val_accuracy: 0.8467 - val_loss: 0.4425 - learning_rate: 1.0000e-04
# Epoch 6/30
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 699s 8s/step - accuracy: 0.8687 - loss: 0.3587 - val_accuracy: 0.8711 - val_loss: 0.3870 - learning_rate: 1.0000e-04
# Epoch 7/30
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 710s 8s/step - accuracy: 0.8761 - loss: 0.3349 - val_accuracy: 0.8415 - val_loss: 0.4322 - learning_rate: 1.0000e-04
# Epoch 8/30
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 714s 9s/step - accuracy: 0.8903 - loss: 0.2994 - val_accuracy: 0.8693 - val_loss: 0.3704 - learning_rate: 1.0000e-04
# Epoch 9/30
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 733s 8s/step - accuracy: 0.8996 - loss: 0.2667 - val_accuracy: 0.8728 - val_loss: 0.3638 - learning_rate: 1.0000e-04
# Epoch 10/30
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 756s 9s/step - accuracy: 0.9141 - loss: 0.2351 - val_accuracy: 0.8815 - val_loss: 0.3613 - learning_rate: 1.0000e-04
# Epoch 11/30
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 696s 8s/step - accuracy: 0.9234 - loss: 0.2221 - val_accuracy: 0.8693 - val_loss: 0.3676 - learning_rate: 1.0000e-04
# Epoch 12/30
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 709s 8s/step - accuracy: 0.9260 - loss: 0.2011 - val_accuracy: 0.8763 - val_loss: 0.3498 - learning_rate: 1.0000e-04
# Epoch 13/30
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 731s 8s/step - accuracy: 0.9275 - loss: 0.2019 - val_accuracy: 0.8850 - val_loss: 0.3462 - learning_rate: 1.0000e-04
# Epoch 14/30
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 707s 8s/step - accuracy: 0.9382 - loss: 0.1771 - val_accuracy: 0.8850 - val_loss: 0.3497 - learning_rate: 1.0000e-04
# Epoch 15/30
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 711s 8s/step - accuracy: 0.9464 - loss: 0.1655 - val_accuracy: 0.8937 - val_loss: 0.3362 - learning_rate: 1.0000e-04
# Epoch 16/30
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 654s 8s/step - accuracy: 0.9442 - loss: 0.1676 - val_accuracy: 0.8850 - val_loss: 0.3401 - learning_rate: 1.0000e-04
# Epoch 17/30
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 604s 7s/step - accuracy: 0.9501 - loss: 0.1509 - val_accuracy: 0.8850 - val_loss: 0.3401 - learning_rate: 1.0000e-04
# Epoch 18/30
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 623s 7s/step - accuracy: 0.9572 - loss: 0.1429 - val_accuracy: 0.8815 - val_loss: 0.3420 - learning_rate: 2.0000e-05
# Epoch 19/30
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 619s 7s/step - accuracy: 0.9561 - loss: 0.1307 - val_accuracy: 0.8902 - val_loss: 0.3365 - learning_rate: 2.0000e-05
# Epoch 20/30
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 617s 7s/step - accuracy: 0.9509 - loss: 0.1326 - val_accuracy: 0.8885 - val_loss: 0.3370 - learning_rate: 4.0000e-06

# %%
plt.figure(figsize=(8, 5))

plt.plot(
    history.history["accuracy"],
    label="Training Accuracy"
)

plt.plot(
    history.history["val_accuracy"],
    label="Validation Accuracy"
)

plt.title("DenseNet121 Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()
plt.grid(True)

plt.show()

# %%
plt.figure(figsize=(8, 5))

plt.plot(
    history.history["loss"],
    label="Training Loss"
)

plt.plot(
    history.history["val_loss"],
    label="Validation Loss"
)

plt.title("DenseNet121 Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.grid(True)

plt.show()

# %%
test_loss, test_accuracy = model.evaluate(test_ds)

print("Test Loss:", test_loss)
print("Test Accuracy:", test_accuracy)
# Out:
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 129s 7s/step - accuracy: 0.9075 - loss: 0.2442
# Test Loss: 0.2442093789577484
# Test Accuracy: 0.9075043797492981

# %%
y_true = []
y_pred = []

for images, labels in test_ds:

    predictions = model.predict(images, verbose=0)

    y_true.extend(np.argmax(labels.numpy(), axis=1))
    y_pred.extend(np.argmax(predictions, axis=1))

# %%
cm = confusion_matrix(y_true, y_pred)

# %%
plt.figure(figsize=(8, 6))

sns.heatmap(
    cm,
    annot=True,
    fmt="d",
    cmap="Blues",
    xticklabels=class_names,
    yticklabels=class_names
)

plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("DenseNet121 Confusion Matrix")

plt.show()

# %%
print(
    classification_report(
        y_true,
        y_pred,
        target_names=class_names
    )
)
# Out:
#                precision    recall  f1-score   support
#
#        Eczema       0.96      0.95      0.95       232
# Leishmaniasis       0.78      0.81      0.79       113
#         Tinea       0.92      0.92      0.92       228
#
#      accuracy                           0.91       573
#     macro avg       0.89      0.89      0.89       573
#  weighted avg       0.91      0.91      0.91       573

# %%
MODEL_PATH = "/content/drive/MyDrive/dataset/DenseNet121_Tinea_change_dense_layer.keras"

model.save(MODEL_PATH)

print("Model saved successfully!")
# Out:
# Model saved successfully!
